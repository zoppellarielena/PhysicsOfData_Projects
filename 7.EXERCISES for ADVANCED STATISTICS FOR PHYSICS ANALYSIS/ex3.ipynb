# %% [markdown]
# ## Exercise 1

# %%
tri<-function(x,a,b){
    c<-(b+a)/2 #it can be chosen whatever other rule for c, the only condition is that a<c<b
    if (x>=a & x<c){
        r<-2*(x-a)/((b-a)*(c-a))
    }
    else if (x>=c & x<=b){
        r<-2*(b-x)/((b-a)*(b-c))
    }
    else{
        r<-0
    }
    return(r)
}

#a) plot the function, given the interval (a, b)
tri<-Vectorize(tri)
range<-seq(from=0, to=100,by=1)
plot(range,tri(range,10,90),type="l",col="orange",lwd="2",xlab="x",ylab="f(x)",main="Triangular Distribution [10,90]")
grid()
# Out:
# Plot with title "Triangular Distribution [10,90]"

# %% [markdown]
# To generate the sampling function, the analytical forms of the cumulative and then of the quantile function are required.

# %% [markdown]
# Analytical form of the cumulative:
# $$
# cdf(x)=
# \begin{equation}
# \begin{cases}
# \frac{2}{(b-a)(c-a)} \int_{a}^{x}{dx'(x'-a)} = \frac{(x-a)^2}{(b-a)(c-a)}\textit{  }\textit{  }\textit{  }  \textit{     if } a \leq x < c \\
# \frac{2}{(b-a)(b-c)} \int_{c}^{x}{dx'(b-x')} = 1-\frac{(x-b)^2}{(b-a)(b-c)}\textit{  }\textit{  }\textit{  }   \textit{     if } c \leq x \leq b \\
# 0  \textit{     else}
# \end{cases}
# \end{equation}
# $$

# %% [markdown]
# The condition on the probability p for the quantile function is:
# $$
# cdf(c)=\frac{c-a}{b-a}
# $$

# %% [markdown]
# Analytical form of the quantile function:
# $$
# q(p)=cdf^{-1}(p)=
# \begin{cases}
# \sqrt{p(b-a)(c-a)}+a \textit{  }\textit{  }\textit{  } \textit{   if   } 0 \leq p < \frac{c-a}{b-a} \\
# b - \sqrt{(b-c)(1-p)(b-a)} \textit{  }\textit{  }\textit{  }  \textit{    if    } \frac{c-a}{b-a} \leq p \leq 1
# \end{cases}
# $$

# %%
#b) and write an algorithm to generate random numbers from the triangular distribution

samp <- function(n, a, b){
    c<-(b+a)/2
    d<-(c−a)/(b−a)
    rand <- runif(n, 0, 1)
    r <- ifelse((rand <d),
                a + sqrt((b-a)*(c-a)*rand),
                b - sqrt((b-a)*(b-c)*(1-rand))
               )
    return(r)
}

# %%
#c) generate 10^4 random number from the distribution, show them in an histogram and superimpose the analytical curve
data<-samp(10^4,10,90)
histo<-hist(data, breaks=seq(0,100,l=21),col="orchid",xlab="x",main="Samplings of 10^4 random numbers",border="white")
lines(range, 10^4*(histo$breaks[2]-histo$breaks[1])*tri(range, 10,90), lwd=2, col="navyblue", lty="dashed")
# Out:
# Plot with title "Samplings of 10^4 random numbers"

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# a) Exponential distribution

# %%
M_exp<-function(k){
    return(1/k)
}
G_exp<-function(k){
    return(1-pexp(k,1))
}
k_range<-seq(from=0,to=5,by=0.1)
prob<-seq(from=0,to=1,by=1/50)
plot(k_range, prob, type="n",xlab="k",ylab="P[X>=k]",main="Exponential Distribution with mean=1")
lines(k_range, M_exp(k_range),col="deepskyblue",lwd="4")
lines(k_range, G_exp(k_range),col="dodgerblue4",lwd="2",type="b")
grid()
legend(3,0.7,legend=c("Markov's inequality","G(k)=1-F(k)"),lty=c(1,1),lwd=c(4,2),col=c("deepskyblue", "dodgerblue4"))
# Out:
# Plot with title "Exponential Distribution with mean=1"

# %% [markdown]
# b) Uniform Distribution

# %%
M_uni<-function(k){
    return(4/k)
}
G_uni<-function(k){
    return(1-punif(k,3,5))
}
k_range_uni<-seq(from=0,to=10,by=0.1) #for a better visualization
prob_uni<-seq(from=0,to=1,by=1/100)
plot(k_range_uni, prob_uni, type="n",xlab="k",ylab="P[X>=k]",main="Uniform Distribution [3,5]")
lines(k_range_uni, M_uni(k_range_uni),col="darkolivegreen1",lwd="4")
lines(k_range_uni, G_uni(k_range_uni),col="darkolivegreen4",lwd="2",type="b")
grid()
legend(6,0.3,legend=c("Markov's inequality","G(k)=1-F(k)"),lty=c(1,1),lwd=c(2,4),col=c("darkolivegreen1", "darkolivegreen4"))
# Out:
# Plot with title "Uniform Distribution [3,5]"

# %% [markdown]
# c) Binomial Distribution

# %%
M_bin<-function(k){
    return(0.5/k)
}
G_bin<-function(k){
    return(1-pbinom(k,size=1,prob=0.5))
}
prob_bin<-seq(from=0,to=0.5,by=1/100) #for a better visualization
plot(k_range, prob_bin, type="n",xlab="k",ylab="P[X>=k]",main="Binomial Distribution with n=1, p=0.5")
lines(k_range, M_bin(k_range),col="orange",lwd="4")
lines(k_range, G_bin(k_range),col="indianred1",lwd="2",type="b")
grid()
legend(3,0.4,legend=c("Markov's inequality","G(k)=1-F(k)"),lty=c(1,1),lwd=c(2,4),col=c("orange", "indianred1"))
# Out:
# Plot with title "Binomial Distribution with n=1, p=0.5"

# %% [markdown]
# d) Poisson distribution

# %%
M_p<-function(k){
    return(0.5/k)
}
G_p<-function(k){
    return(1-ppois(k,0.5))
}
plot(k_range, prob_bin, type="n",xlab="k",ylab="P[X>=k]",main="Poisson Distribution with lambda=0.5")
lines(k_range, M_p(k_range),col="mediumorchid1",lwd="4")
lines(k_range, G_p(k_range),col="mediumpurple3",lwd="2",type="b")
grid()
legend(3,0.4,legend=c("Markov's inequality","G(k)=1-F(k)"),lty=c(1,1),lwd=c(2,4),col=c("mediumorchid1", "mediumpurple3"))
# Out:
# Plot with title "Poisson Distribution with lambda=0.5"

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# a) Normal distribution

# %%
Cheb<-function(k){
    return(1-1/k^2)
}
F_norm<- function(k, mu, sigma){
            pnorm(3+k*5, 3, 5)-pnorm(3-k*5, 3, 5)
        }
k_range<-seq(from=0,to=5,by=0.1)
prob<-seq(from=0,to=1,by=1/50)
plot(k_range, prob,xlab="k",ylab="P[|X-mu|<k*sigma]",main="Normal Distribution with mean=3, sigma=5",type="n")
lines(k_range, Cheb(k_range), col="rosybrown1",lwd="4")
lines(k_range, F_norm(k_range),col="violetred3",lwd="2",type="b")
grid()
legend(2.5,0.4,legend=c("Chebyshev’s inequality","P[|X-mu|<k*sigma]"),lty=c(1,1),lwd=c(4,2),col=c("rosybrown1", "violetred3"))
# Out:
# Plot with title "Normal Distribution with mean=3, sigma=5"

# %% [markdown]
# b) Exponential distribution

# %% [markdown]
# Since $\lambda = 1$, $\sigma=\sqrt{\frac{1}{\lambda^2}}=1$

# %%
F_exp<- function(k, mu, sigma){
            pexp(1+k, 1)-pexp(1-k, 1)
        }
plot(k_range, prob,xlab="k",ylab="P[|X-mu|<k*sigma]",main="Exponential Distribution with lambda=1",type="n")
lines(k_range, Cheb(k_range), col="deepskyblue",lwd="4")
lines(k_range, F_exp(k_range),col="dodgerblue4",lwd="2",type="b")
grid()
legend(2.5,0.4,legend=c("Chebyshev’s inequality","P[|X-mu|<k*sigma]"),lty=c(1,1),lwd=c(4,2),col=c("deepskyblue", "dodgerblue4"))
# Out:
# Plot with title "Exponential Distribution with lambda=1"

# %% [markdown]
# c) Uniform Distribution

# %% [markdown]
# $$
# \mu=\frac{a+b}{2}=1 \textit{   }\textit{   }\textit{therefore,}\textit{   }\textit{   }
# \sigma=\sqrt{\frac{(b-a)^2}{12}}= \sqrt{\frac{2}{3}}
# $$

# %%
F_uni<- function(k, mu, sigma){
            punif(1+k*sqrt(2/3), 1-sqrt(2),1+sqrt(2))-punif(1-k*sqrt(2/3), 1-sqrt(2),1+sqrt(2))
        }
plot(k_range, prob,xlab="k",ylab="P[|X-mu|<k*sigma]",main="Uniform Distribution [1-sqrt(2),1+sqrt(2)]",type="n")
lines(k_range, Cheb(k_range), col="darkolivegreen1",lwd="4")
lines(k_range, F_uni(k_range),col="darkolivegreen4",lwd="2",type="b")
grid()
legend(2.5,0.4,legend=c("Chebyshev’s inequality","P[|X-mu|<k*sigma]"),lty=c(1,1),lwd=c(4,2),col=c("darkolivegreen1", "darkolivegreen4"))
# Out:
# Plot with title "Uniform Distribution [1-sqrt(2),1+sqrt(2)]"

# %% [markdown]
# d) Poisson distribution

# %% [markdown]
# Since $\lambda=\frac{1}{3}$:
# $$
# \sigma= \sqrt{\frac{1}{3}}
# $$

# %%
F_p<- function(k, mu, sigma){
            ppois(1/3+k*sqrt(1/3), 1/3)-ppois(1/3-k*sqrt(1/3), 1/3)
        }
plot(k_range, prob,xlab="k",ylab="P[|X-mu|<k*sigma]",main="Poisson Distribution with lambda=1/3",type="n")
lines(k_range, Cheb(k_range), col="mediumorchid1",lwd="4")
lines(k_range, F_p(k_range),col="mediumpurple3",lwd="2",type="b")
grid()
legend(2.5,0.4,legend=c("Chebyshev’s inequality","P[|X-mu|<k*sigma]"),lty=c(1,1),lwd=c(4,2),col=c("mediumorchid1", "mediumpurple3"))
# Out:
# Plot with title "Poisson Distribution with lambda=1/3"

# %% [markdown]
# ## Exercise 4

# %%
n<-14 #number of trials
trials<-seq(from=1,to=n,by=1)
#Now I define the two possibile probabilities of extracting a colored stone given Hj
p_w<-function(j){
    return(j/5)
    }
p_b<-function(j){
    return(1-j/5)
}
E_w<-0.5 #initial probability of extracting a white stone (this value will be use for the normalization)
E_b<-0.5
H<-c(1/6,1/6,1/6,1/6,1/6,1/6) #collection of all the initial H_j probabilities
H_all<-matrix(,nrow=length(trials),ncol=6) #I create a matrix to collect all the H_j values
for (j in trials){
    cat("\nTrial",j,":")
    control<-FALSE
    while (control==FALSE){
        color <- readline(prompt="Enter the stone color (B/W): ") #The colors are inserted manually
        if (color=="W" | color=="B"){
            control=TRUE
        } else {control=FALSE}
    }
    if (color=="W"){
        p_EH<-p_w
        E<-E_w
        cat("\nWhite is extracted") #control
    } else if (color=="B") {
        p_EH<-p_b
        E<-E_b
        cat("\nBlack is extracted") #control
    }
    cat("\nThe probability of each box is:")
    for (i in 1:6){
        H[i]=(H[i]*p_EH(i-1))/E #Updating the bayesian probability for each step
        cat("\nBox",i-1,":",round(H[i],digits=3))
        H_all[j,i]<-H[i]
    }
    add_w<-vector() #used to update the value of E_w
    for (i in 1:6){
        add_w[i]<-H[i]*p_w(i-1)
    }
    E_w=sum(add_w)
    add_b<-vector() #used to update the value of E_b
    for (i in 1:6){
        add_b[i]<-H[i]*p_b(i-1)
    }
    E_b=sum(add_b)
    cat("\nP(E_w|I) is:",round(E_w,digits=3))
    cat("\nP(E_b|I) is:",round(E_b,digits=3))
    cat("\n---------")
}
box.guess<-which(H_all==max(H_all[n,]),arr.ind=TRUE)
guess<-box.guess[1,2]-1
cat("\nThe guessed BOX is number:",guess)
# Out:
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): B
# Enter the stone color (B/W): W
#
# Trial 1 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.333
# Box 1 : 0.267
# Box 2 : 0.2
# Box 3 : 0.133
# Box 4 : 0.067
# Box 5 : 0
# P(E_w|I) is: 0.267
# P(E_b|I) is: 0.733
# ---------
# Trial 2 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.455
# Box 1 : 0.291
# Box 2 : 0.164
# Box 3 : 0.073
# Box 4 : 0.018
# Box 5 : 0
# P(E_w|I) is: 0.182
# P(E_b|I) is: 0.818
# ---------
# Trial 3 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.556
# Box 1 : 0.284
# Box 2 : 0.12
# Box 3 : 0.036
# Box 4 : 0.004
# Box 5 : 0
# P(E_w|I) is: 0.13
# P(E_b|I) is: 0.87
# ---------
# Trial 4 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.638
# Box 1 : 0.261
# Box 2 : 0.083
# Box 3 : 0.016
# Box 4 : 0.001
# Box 5 : 0
# P(E_w|I) is: 0.096
# P(E_b|I) is: 0.904
# ---------
# Trial 5 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.706
# Box 1 : 0.231
# Box 2 : 0.055
# Box 3 : 0.007
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.073
# P(E_b|I) is: 0.927
# ---------
# Trial 6 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.762
# Box 1 : 0.2
# Box 2 : 0.036
# Box 3 : 0.003
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.056
# P(E_b|I) is: 0.944
# ---------
# Trial 7 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.807
# Box 1 : 0.169
# Box 2 : 0.023
# Box 3 : 0.001
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.044
# P(E_b|I) is: 0.956
# ---------
# Trial 8 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.844
# Box 1 : 0.142
# Box 2 : 0.014
# Box 3 : 0.001
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.034
# P(E_b|I) is: 0.966
# ---------
# Trial 9 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.874
# Box 1 : 0.117
# Box 2 : 0.009
# Box 3 : 0
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.027
# P(E_b|I) is: 0.973
# ---------
# Trial 10 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.898
# Box 1 : 0.096
# Box 2 : 0.005
# Box 3 : 0
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.022
# P(E_b|I) is: 0.978
# ---------
# Trial 11 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.918
# Box 1 : 0.079
# Box 2 : 0.003
# Box 3 : 0
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.017
# P(E_b|I) is: 0.983
# ---------
# Trial 12 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.934
# Box 1 : 0.064
# Box 2 : 0.002
# Box 3 : 0
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.014
# P(E_b|I) is: 0.986
# ---------
# Trial 13 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.947
# Box 1 : 0.052
# Box 2 : 0.001
# Box 3 : 0
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.011
# P(E_b|I) is: 0.989
# ---------
# Trial 14 :
# White is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.954
# Box 2 : 0.045
# Box 3 : 0
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.209
# P(E_b|I) is: 0.791
# ---------
# The guessed BOX is number: 1

# %%
#PLOTS
for (p in 1:6){
    name=paste("Box H",p-1)
    plot(trials,H_all[,p],main=name,type="b",lwd="3",col="aquamarine",xlab="Extraction Step",ylab="P(H|E)")
    grid()
}
# Out:
# Plot with title "Box H 0"
# Plot with title "Box H 1"
# Plot with title "Box H 2"
# Plot with title "Box H 3"
# Plot with title "Box H 4"
# Plot with title "Box H 5"

# %% [markdown]
# ## Exercise 5

# %%
n<-20 #number of trials
num<-sample(0:5, 1) #It causally choose the number of the box
box<-rbinom(n,1,num/5) #generate samples from the chosen box
trials<-seq(from=1,to=n,by=1)
#Now I define the two possibile probabilities of extracting a colored stone given Hj
p_w<-function(j){
    return(j/5)
    }
p_b<-function(j){
    return(1-j/5)
}
E_w<-0.5 #initial probability of extracting a white stone (this value will be use for the normalization)
E_b<-0.5
H<-c(1/6,1/6,1/6,1/6,1/6,1/6) #collection of all the initial H_j probabilities
H_all<-matrix(,nrow=length(trials),ncol=6) #I create a matrix to collect all the H_j values
for (j in trials){
    cat("\nTrial",j,":")
    a<-box[j]
    if (a==1){
        color<-"W"
        p_EH<-p_w
        E<-E_w
        cat("\nWhite is extracted")
    } else if (a==0) {
        color<-"B"
        p_EH<-p_b
        E<-E_b
        cat("\nBlack is extracted")
    }
    cat("\nThe probability of each box is:")
    for (i in 1:6){
        H[i]=(H[i]*p_EH(i-1))/E #Updating the bayesian probability for each step
        cat("\nBox",i-1,":",round(H[i],digits=3))
        H_all[j,i]<-H[i]
    }
    add_w<-vector() #used to update the value of E_w
    for (i in 1:6){
        add_w[i]<-H[i]*p_w(i-1)
    }
    E_w=sum(add_w)
    add_b<-vector() #used to update the value of E_b
    for (i in 1:6){
        add_b[i]<-H[i]*p_b(i-1)
    }
    E_b=sum(add_b)
    cat("\nP(E_w|I) is:",round(E_w,digits=3))
    cat("\nP(E_b|I) is:",round(E_b,digits=3))
    cat("\n---------")
}
box.guess<-which(H_all==max(H_all[n,]),arr.ind=TRUE)
guess<-box.guess[1,2]-1
cat("\nThe guessed BOX is number:",guess)
cat("\nThe true BOX is number:",num) #this time we can check if our prediction is right
if(guess==num){
    cat("\nThe prediction is right.")
} else{
    cat("\nThe prediction is wrong.")
}
# Out:
# Trial 1 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.333
# Box 1 : 0.267
# Box 2 : 0.2
# Box 3 : 0.133
# Box 4 : 0.067
# Box 5 : 0
# P(E_w|I) is: 0.267
# P(E_b|I) is: 0.733
# ---------
# Trial 2 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.455
# Box 1 : 0.291
# Box 2 : 0.164
# Box 3 : 0.073
# Box 4 : 0.018
# Box 5 : 0
# P(E_w|I) is: 0.182
# P(E_b|I) is: 0.818
# ---------
# Trial 3 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.556
# Box 1 : 0.284
# Box 2 : 0.12
# Box 3 : 0.036
# Box 4 : 0.004
# Box 5 : 0
# P(E_w|I) is: 0.13
# P(E_b|I) is: 0.87
# ---------
# Trial 4 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.638
# Box 1 : 0.261
# Box 2 : 0.083
# Box 3 : 0.016
# Box 4 : 0.001
# Box 5 : 0
# P(E_w|I) is: 0.096
# P(E_b|I) is: 0.904
# ---------
# Trial 5 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0.706
# Box 1 : 0.231
# Box 2 : 0.055
# Box 3 : 0.007
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.073
# P(E_b|I) is: 0.927
# ---------
# Trial 6 :
# White is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.636
# Box 2 : 0.302
# Box 3 : 0.06
# Box 4 : 0.002
# Box 5 : 0
# P(E_w|I) is: 0.286
# P(E_b|I) is: 0.714
# ---------
# Trial 7 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.712
# Box 2 : 0.254
# Box 3 : 0.033
# Box 4 : 0.001
# Box 5 : 0
# P(E_w|I) is: 0.264
# P(E_b|I) is: 0.736
# ---------
# Trial 8 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.775
# Box 2 : 0.207
# Box 3 : 0.018
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.249
# P(E_b|I) is: 0.751
# ---------
# Trial 9 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.825
# Box 2 : 0.165
# Box 3 : 0.01
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.237
# P(E_b|I) is: 0.763
# ---------
# Trial 10 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.865
# Box 2 : 0.13
# Box 3 : 0.005
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.228
# P(E_b|I) is: 0.772
# ---------
# Trial 11 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.896
# Box 2 : 0.101
# Box 3 : 0.003
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.221
# P(E_b|I) is: 0.779
# ---------
# Trial 12 :
# White is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.81
# Box 2 : 0.183
# Box 3 : 0.007
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.239
# P(E_b|I) is: 0.761
# ---------
# Trial 13 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.852
# Box 2 : 0.144
# Box 3 : 0.004
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.23
# P(E_b|I) is: 0.77
# ---------
# Trial 14 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.886
# Box 2 : 0.112
# Box 3 : 0.002
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.223
# P(E_b|I) is: 0.777
# ---------
# Trial 15 :
# White is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.794
# Box 2 : 0.201
# Box 3 : 0.005
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.242
# P(E_b|I) is: 0.758
# ---------
# Trial 16 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.838
# Box 2 : 0.159
# Box 3 : 0.003
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.233
# P(E_b|I) is: 0.767
# ---------
# Trial 17 :
# White is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.719
# Box 2 : 0.273
# Box 3 : 0.007
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.258
# P(E_b|I) is: 0.742
# ---------
# Trial 18 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.775
# Box 2 : 0.221
# Box 3 : 0.004
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.246
# P(E_b|I) is: 0.754
# ---------
# Trial 19 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.822
# Box 2 : 0.176
# Box 3 : 0.002
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.236
# P(E_b|I) is: 0.764
# ---------
# Trial 20 :
# Black is extracted
# The probability of each box is:
# Box 0 : 0
# Box 1 : 0.861
# Box 2 : 0.138
# Box 3 : 0.001
# Box 4 : 0
# Box 5 : 0
# P(E_w|I) is: 0.228
# P(E_b|I) is: 0.772
# ---------
# The guessed BOX is number: 1
# The true BOX is number: 1
# The prediction is right.

# %%
#PLOTS
for (p in 1:6){
    name=paste("Box H",p-1)
    plot(trials,H_all[,p],main=name,type="b",lwd="3",col="orchid",xlab="Trial",ylab="P(H|E)")
    grid()
}
# Out:
# Plot with title "Box H 0"
# Plot with title "Box H 1"
# Plot with title "Box H 2"
# Plot with title "Box H 3"
# Plot with title "Box H 4"
# Plot with title "Box H 5"
